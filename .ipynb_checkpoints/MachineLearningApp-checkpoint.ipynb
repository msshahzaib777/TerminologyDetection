# %%
import os
import nltk
import pandas as pd
from unidecode import unidecode

# %%
dataPath = ".\\data"

# %%
def find_files(search_path):
    result = []
    # Wlaking top-down from the root
    for root, dir, files in os.walk(search_path):
        for file in files:       
                result.append(os.path.join(root, file))
    return result

# %%
trainFiles = find_files(dataPath + "\\train")
testFiles = find_files(dataPath + "\\test")
devFiles = find_files(dataPath + "\\dev")

# %%
def loadData(paths):
    data = pd.DataFrame(columns=["tokens", "label"])
    for i in paths:
        try:
            doc = pd.read_csv(i, sep="\t", names=["tokens", "label"], header=None)
            doc['file'] = i[12:-5]
            data = pd.concat([data, doc], ignore_index=True)
        except Exception as e: 
            print(i, e)
    return data

# %%
train = loadData(trainFiles)
test  = loadData(testFiles)
dev = loadData(devFiles)
print("Training Size before Cleaning")
print("Training Size:\t", train.shape)
print("Test Size:\t", test.shape)
print("Dev Size:\t", dev.shape)
# Out:
# Training Size before Cleaning
# Training Size:	 (21549, 3)
# Test Size:	 (2781, 3)
# Dev Size:	 (2414, 3)

# %%
def stripSpaces(x):
    x = unidecode(x)
    specialchar = "!@#$%^&*()[]{};:,./<>?\|`-~=_+\t\n"
    for tag in specialchar:
        x = x.replace(tag, '')
    x = x.replace(" ", "")
    x = x.lower()
    x = x.strip()
    return x

def cleaning(dataset):
    dataset.drop(dataset[dataset["tokens"].isna()].index, inplace=True)
    print("Size after Dropping Null Tokens",dataset.shape)
    print("Tokens Without labels:")
    for indexWithNullLabel in dataset[dataset["label"].isna()].index:
        token = dataset["tokens"][indexWithNullLabel]
        #split with ' ' doesnt consider multiple spaces as one
        tokenslist = token.split()
        dataset["tokens"][indexWithNullLabel] = tokenslist[0]

        if (len(tokenslist) > 1):
            dataset["label"][indexWithNullLabel] = tokenslist[1]
        else:
            print(dataset.loc[indexWithNullLabel, :])
            #Manual Correction for 5467 and 5858 (very & research)
            dataset["label"][indexWithNullLabel] = 'O'
            print("Manual Corrected:", dataset["tokens"][indexWithNullLabel])
    dataset = dataset.applymap(stripSpaces)
    #label to handel 0, i*, b*, o*, 0*
    dataset[dataset["label"] == 'ii'] = 'i'
    dataset[dataset["label"] == '0'] = 'o'
    print("Removing special characters")
    specialCharTokens = dataset[~(dataset["tokens"].str.isalnum())]["tokens"].unique()
    #for sprecialChar with label B, moving label to next row and droping rows  
    specialCharWithB = dataset[dataset["tokens"].isin(specialCharTokens) & (dataset["label"] == 'b')].index
    for i in specialCharWithB:
        dataset.loc[i+1, "label"] = 'b'
    dataset.drop(dataset[dataset["tokens"].isin(specialCharTokens) & ((dataset["label"] == 'o') | (dataset["label"] == 'b') )].index, inplace=True)
    #Drop i where there is i and b before it
    toDrop = []
    for i in dataset[dataset["tokens"].isin(specialCharTokens)].index:
        if(dataset["label"][i-1] == 'b' or dataset["label"][i-1] == 'i' ):
            toDrop.append(i)
        else:
            dataset["label"][i] = 'b'
    dataset.drop(toDrop, axis=0, inplace=True)
    print(dataset.value_counts()[:30])
    print("Removing Stopwords based on above listed most frequent words")
    stopwords = ["the","this","that","has","have","can","be","in","on","at","to","as","is","are","a","an","with","our","we","from","which","when","also","and","or","not","it","its",
                 "than","use","into","how","but","to","for","their","there","all"]
    print("Label order correction:")
    dataset.reset_index(drop=True, inplace=True)
    temp = dataset.copy()
    temp["before"] = temp["label"].shift(1)
    temp["after"] = temp["label"].shift(-1)
    for i in temp[(temp["label"] == 'i') & (temp["before"] == 'o') ].index:
            # oio or oii
            print(temp.loc[i-1, "tokens"]+"("+temp.loc[i-1, "label"]+")\t\t", temp.loc[i, "tokens"]+"("+temp.loc[i, "label"]+")\t\t", temp.loc[i+1, "tokens"]+"("+temp.loc[i+1, "label"]+")")
            if(temp.loc[i+1, "label"] == 'o' or temp.loc[i+1, "label"] == 'i'):
                dataset.loc[i, "label"] = 'b'
            # oib
            if(temp.loc[i+1, "label"] == 'b'):
                dataset.loc[i, "label"] = 'b'
                dataset.loc[i+1, "label"] = 'i'
    del temp
    dataset.reset_index(drop=True, inplace=True)
    return dataset

# %%
train = cleaning(train)
# Out:
# Size after Dropping Null Tokens (21487, 3)
# Tokens Without labels:
# tokens                    .
# label                   NaN
# file      \2009-35-1-29-46.
# Name: 107, dtype: object
# Manual Corrected: .
# tokens                    very
# label                      NaN
# file      \2013-39-3-511–554 .
# Name: 7108, dtype: object
# Manual Corrected: very
# tokens               research
# label                     NaN
# file      \2013-39-4-847–884.
# Name: 7557, dtype: object
# Manual Corrected: research
# Removing special characters
# tokens  label  file
# the     o      2015411120       23
#                2016421121161    22
#                2011374657688    21
#                2016422245275    21
#                20154112140      20
# of      o      2016421121161    20
# the     o      2009351328       20
#                2012383527574    20
#                2013391121160    20
# of      o      2011374657688    19
# the     o      2016424661701    19
#                2020461152       19
#                2015412185214    18
#                2011374753809    18
#                202147169116     18
# and     o      2013393555590    18
# the     o      2019451163197    17
# of      o      202147169116     16
# the     o      2009353399433    16
#                201036171109     16
#                2017434683722    15
#                2021471117140    15
# a       o      2013391121160    15
# of      o      2015411120       15
# the     o      2019451137161    15
#                2017433521565    15
#                2010362159201    15
#                2013392267300    14
# that    o      2011374753809    14
# the     o      2013392229266    13
# dtype: int64
# Removing Stopwords based on above listed most frequent words
# Label order correction:
# successful(o)		 techniques(i)		 and(o)
# 2003(o)		 parsing(i)		 model(i)
# authorship(o)		 attribution(i)		 of(o)
# on(o)		 error(i)		 correction(i)
# of(o)		 compositionality(i)		 with(o)
# the(o)		 models(i)		 and(o)
# a(o)		 complex(i)		 graph(b)
# into(o)		 simple(i)		 subgraphs(b)

# %%
stopwords = ["the","this","that","has","have","can","be","in","on","at","to","as","is","are","a","an","with","our","we","from","which","when","also","and","or","not","it","its",
                 "than","use","into","how","but","to","for","their","there","all"]

# %%
train[(train["tokens"].isin(stopwords)) & (train["label"] != 'o')].value_counts()

# %%
tokens = []
tokens.extend(train["tokens"].tolist())
tokenset = set(tokens)
print("Unique Tokens in Train and dev set: ",len(tokenset))
tokenset
#[x for x in tokenset if len(x)<=1]

# %%
#removing stopwords with o to investigate stopwords with b and i
temp = train.copy()
temp.drop(temp[(temp["tokens"].isin(stopwords)) & (temp["label"] == 'o')].index, axis=0, inplace=True)
temp.reset_index(drop=True, inplace=True)

# %%
temp[(temp["tokens"].isin(stopwords))].value_counts()
# temp[(temp["tokens"].isin(stopwords))]["tokens"].value_counts().index
# Out:
# tokens  label  file
# to      i      2019452267292    5
# the     i      2017434683722    4
#                2013394847884    2
#                2018443403446    2
# and     i      2018443447482    2
# to      i      20093512946      2
# and     i      2017431181200    2
#                2016424661701    2
# to      i      2021472309332    2
#                2021472445476    2
# a       i      2017434781835    2
# the     i      2017434781835    2
#                2017431125179    1
#                2016421121161    1
#                2017431181200    1
#                201743171123     1
#                2017433521565    1
# a       i      2017434683722    1
# the     i      2017434723760    1
#                2018442349374    1
#                20133912355      1
# their   i      2017431181200    1
# to      i      2014402349401    1
#                2020461152       1
# with    i      2017433465520    1
# the     i      2019451163197    1
#                2010363303339    1
#                2013391195227    1
# are     i      2017434781835    1
# all     b      2017433465520    1
#         i      2017434781835    1
# an      i      2017431125179    1
# and     i      201036171109     1
#                201440185120     1
#                2016423391419    1
#                2018442329348    1
#                2020461152       1
# for     i      2019452229265    1
# the     i      2010362247277    1
# for     i      2021472309332    1
# from    b      201743171123     1
# in      b      2009353313343    1
#         i      201743171123     1
#                2017434683722    1
# on      i      2014401171202    1
#                201743171123     1
# the     i      2010362203227    1
# with    i      2017434683722    1
# dtype: int64

# %%
# temp[(temp["tokens"].isin(stopwords))].value_counts()
# of and the is often used in between 
#Arabic NER only NER is Keyword

for i in temp[(temp["tokens"].isin(temp[(temp["tokens"].isin(stopwords))]["tokens"].value_counts().index))].index:
    print(temp.loc[i, 'file'] +":"+
          temp.loc[i-2, 'tokens']+"(" + temp.loc[i-2, 'label'] +") "+ temp.loc[i-1, 'tokens']+"(" + temp.loc[i-1, 'label'] +") "+
          temp.loc[i, 'tokens']+"(" + temp.loc[i, 'label'] +") "+ temp.loc[i+1, 'tokens']+"(" + temp.loc[i+1, 'label'] +") "+
          temp.loc[i+2, 'tokens']+"(" + temp.loc[i+2, 'label'] +") "+ temp.loc[i+3, 'tokens']+"(" + temp.loc[i+3, 'label'] +") ")
# Out:
# 20093512946:both text to text concept to
# 20093512946:text concept to text generation systems
# 2009353313343:of example in domain training sentences
# 201036171109:of extrinsic and intrinsic measures outcome
# 2010362203227:state of the art classification method
# 2010362247277:state of the art syntax mt
# 2010363303339:state of the art alignment quality
# 2013391195227:state of the art system based
# 20133912355:state of the art data driven
# 2013394847884:state of the art such linking
# 2013394847884:state of the art level participated
# 2014401171202:called arabic on line commentary data
# 201440185120:especially sparse and polysemous words frame
# 2014402349401:languages tree to tree translation evidence
# 2016421121161:state of the art smt model
# 2016423391419:both paradigmatic and syntagmatic relations linguistically
# 2016424661701:of subject and object relative clauses
# 2016424661701:across subject and object relative clauses
# 2017431125179:state of the art several ways
# 2017431125179:by adapting an argumentation model tested
# 2017431181200:blogs characterize the topic of message
# 2017431181200:been analyze their context just pointed
# 2017431181200:hashtags multiple and variable meanings article
# 2017431181200:hashtags similar and synchronous usage patterns
# 201743171123:computational work on metaphor traditionally evolved
# 201743171123:metaphorical association from text order investigate
# 201743171123:them data in three languages different
# 201743171123:state of the i art results
# 2017433465520:similarity measures all subtree kernels compare
# 2017433465520:regarding correlation with human judgments both
# 2017433521565:state of the art performance several
# 2017434683722:methods analyzing the activation patterns of
# 2017434683722:trained predicting the representations of visual
# 2017434683722:trained predict the next word same
# 2017434683722:function position in the sequential structure
# 2017434683722:position in the sequential structure of
# 2017434683722:sensitive words with a syntactic function
# 2017434683722:words with a syntactic function further
# 2017434723760:state of the art le distributional
# 2017434781835:first devise a hierarchical alignment scheme
# 2017434781835:parse trees are aligned way eliminates
# 2017434781835:distribution of the translation divergences shows
# 2017434781835:enough capture the translation divergences point
# 2017434781835:thus building a semantic representation captures
# 2017434781835:representation captures all possible translation divergences
# 2018442329348:testable left and right context k
# 2018442349374:state of the art unsupervised morphological
# 2018443403446:state of the art however systematic
# 2018443403446:state of the art results several
# 2018443447482:vijay shanker and weir 1994 main
# 2018443447482:vijay shanker and weir 1994 apart
# 2019451163197:state of the art matching methods
# 2019452229265:new models for automatic annotation neural
# 2019452267292:based sequence to sequence learning encodes
# 2019452267292:novel end to end syntactic nmt
# 2019452267292:call tree to sequence nmt model
# 2019452267292:extending sequence to sequence model source
# 2019452267292:model sequence to sequence models various
# 2020461152:trained end to end fashion without
# 2020461152:local syntactic and semantic dependencies better
# 2021472309332:studies text to sql problem of
# 2021472309332:annotation network for sql solve complex
# 2021472309332:complex text to sql tasks cross
# 2021472445476:schemes many to one approach translates
# 2021472445476:while one to many approach translates
